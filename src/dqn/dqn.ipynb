# %%
from random import random, randint, sample

import numpy as np
import torch
import torch.nn as nn

import cv2
from tetris import Tetris
from collections import deque

# %% [markdown]
# ## Deep Q Learning Network

# %%
class DQN(nn.Module):
    def __init__(self):
        super(DQN, self).__init__()

        self.conv1 = nn.Sequential(nn.Linear(4, 64), nn.ReLU(inplace=True))
        self.conv2 = nn.Sequential(nn.Linear(64, 64), nn.ReLU(inplace=True))
        self.conv3 = nn.Sequential(nn.Linear(64, 1))

        self._create_weights()

    def _create_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)

        return x

# %%
# DQN for modified environment with increased state space

class DQN(nn.Module):
    def __init__(self, input_size=8):
        super(DQN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(128)
        )

        self.conv2 = nn.Sequential(
            nn.Linear(128, 128),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(128)
        )

        self.conv3 = nn.Sequential(
            nn.Linear(128, 64),
            nn.ReLU(inplace=True)
        )

        # Output layer
        self.output = nn.Linear(64, 1)

        self._create_weights()

    def _create_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.output(x)
        return x

# %% [markdown]
# ## Global Constants

# %%
WIDTH = 10  # Width of board
HEIGHT = 20  # Height of board
BLOCK_SIZE = 30  # Block size when rendering
BATCH_SIZE = 512  # High batch size
LEARNING_RATE = 1e-3
GAMMA = 0.99
INITIAL_EPSILON = 1.0
FINAL_EPSILON = 1e-3
NUM_DECAY_EPOCHS = 1800
NUM_EPOCHS = 3000
SAVE_INTERVAL = 50
REPLAY_MEMORY_SIZE = 28000

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cuda')

# %% [markdown]
# ## Training Loop Using Epsilon Greedy and Experience Replay

# %%
def train():
    torch.manual_seed(42)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(42)

    env = Tetris(width=WIDTH, height=HEIGHT, block_size=BLOCK_SIZE)
    model = DQN().to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
    criterion = nn.MSELoss()

    state = env.reset().to(DEVICE)
    replay_memory = deque(maxlen=REPLAY_MEMORY_SIZE)
    epoch = 0

    while epoch < NUM_EPOCHS:
        next_steps = env.get_next_states()
        # Epsilon Greedy
        epsilon = FINAL_EPSILON + (max(NUM_DECAY_EPOCHS - epoch, 0) * 
                                   (INITIAL_EPSILON - FINAL_EPSILON) / NUM_DECAY_EPOCHS)
        next_actions, next_states = zip(*next_steps.items())
        next_states = torch.stack(next_states).to(DEVICE)

        #print(next_states.shape)

        model.eval()
        with torch.no_grad():
            predictions = model(next_states)[:, 0]
        model.train()

        if random() <= epsilon:
            index = randint(0, len(next_steps) - 1)
        else:
            index = torch.argmax(predictions).item()

        next_state = next_states[index, :]
        action = next_actions[index]

        reward, done = env.step(action, render=False)
        next_state = next_state.to(DEVICE)
        replay_memory.append([state, reward, next_state, done])

        if done:
            final_score = env.score
            final_tetrominoes = env.tetrominoes
            final_cleared_lines = env.cleared_lines
            state = env.reset().to(DEVICE)
        else:
            state = next_state
            continue

        if len(replay_memory) < REPLAY_MEMORY_SIZE / 10:
            continue

        epoch += 1
        batch = sample(replay_memory, min(len(replay_memory), BATCH_SIZE))
        state_batch, reward_batch, next_state_batch, done_batch = zip(*batch)
        state_batch = torch.stack(tuple(state for state in state_batch)).to(DEVICE)
        reward_batch = torch.from_numpy(np.array(reward_batch, dtype=np.float32)[:, None]).to(DEVICE)
        next_state_batch = torch.stack(tuple(state for state in next_state_batch)).to(DEVICE)

        q_values = model(state_batch)
        model.eval()
        with torch.no_grad():
            next_prediction_batch = model(next_state_batch)
        model.train()
 
        # Compute the target Q-values for each transition
        y_values = [
            reward if done else reward + GAMMA * prediction
            for reward, done, prediction in zip(reward_batch, done_batch, next_prediction_batch)
        ]
        y_tensor = torch.tensor(y_values, dtype=torch.float32, device=DEVICE)
        y_batch = y_tensor[:, None]

        optimizer.zero_grad()
        loss = criterion(q_values, y_batch)
        loss.backward()
        optimizer.step()

        print("Epoch: {}/{}, Action: {}, Score: {}, Tetrominoes {}, Cleared lines: {}".format(
            epoch,
            NUM_EPOCHS,
            action,
            final_score,
            final_tetrominoes,
            final_cleared_lines))

        if epoch > 0 and epoch % SAVE_INTERVAL == 0:
            torch.save(model.state_dict(), "policy_net.pth")

    torch.save(model.state_dict(), "policy_net.pth")
    return model

# %%
agent_tetris = train()
# Out:
# Epoch: 1/3000, Action: (6, 0), Score: 37, Tetrominoes 29, Cleared lines: 1
# Epoch: 2/3000, Action: (4, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 3/3000, Action: (5, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 4/3000, Action: (1, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 5/3000, Action: (4, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 6/3000, Action: (4, 3), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 7/3000, Action: (2, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 8/3000, Action: (2, 2), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 9/3000, Action: (4, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 10/3000, Action: (5, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 11/3000, Action: (5, 2), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 12/3000, Action: (3, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 13/3000, Action: (3, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 14/3000, Action: (6, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 15/3000, Action: (3, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 16/3000, Action: (0, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 17/3000, Action: (4, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 18/3000, Action: (3, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 19/3000, Action: (3, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 20/3000, Action: (5, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 21/3000, Action: (5, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 22/3000, Action: (6, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 23/3000, Action: (4, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 24/3000, Action: (5, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 25/3000, Action: (3, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 26/3000, Action: (3, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 27/3000, Action: (0, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 28/3000, Action: (3, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 29/3000, Action: (0, 0), Score: 31, Tetrominoes 33, Cleared lines: 0
# Epoch: 30/3000, Action: (2, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 31/3000, Action: (2, 2), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch: 32/3000, Action: (4, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 33/3000, Action: (4, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 34/3000, Action: (4, 2), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 35/3000, Action: (5, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 36/3000, Action: (3, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 37/3000, Action: (1, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 38/3000, Action: (4, 2), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 39/3000, Action: (5, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 40/3000, Action: (4, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 41/3000, Action: (2, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 42/3000, Action: (3, 0), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 43/3000, Action: (4, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 44/3000, Action: (3, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 45/3000, Action: (7, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 46/3000, Action: (6, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 47/3000, Action: (5, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 48/3000, Action: (4, 3), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 49/3000, Action: (5, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 50/3000, Action: (8, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 51/3000, Action: (4, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 52/3000, Action: (4, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 53/3000, Action: (5, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 54/3000, Action: (4, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 55/3000, Action: (1, 3), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 56/3000, Action: (2, 3), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 57/3000, Action: (5, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 58/3000, Action: (3, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 59/3000, Action: (3, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 60/3000, Action: (4, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 61/3000, Action: (5, 2), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 62/3000, Action: (4, 1), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 63/3000, Action: (2, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 64/3000, Action: (4, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 65/3000, Action: (0, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 66/3000, Action: (7, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 67/3000, Action: (2, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 68/3000, Action: (4, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 69/3000, Action: (5, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 70/3000, Action: (1, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch:
 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 560/3000, Action: (4, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 561/3000, Action: (4, 0), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 562/3000, Action: (5, 3), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 563/3000, Action: (4, 2), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 564/3000, Action: (3, 1), Score: 26, Tetrominoes 28, Cleared lines: 0
# Epoch: 565/3000, Action: (7, 0), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 566/3000, Action: (0, 0), Score: 30, Tetrominoes 32, Cleared lines: 0
# Epoch: 567/3000, Action: (5, 0), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 568/3000, Action: (4, 1), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 569/3000, Action: (7, 3), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 570/3000, Action: (5, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 571/3000, Action: (1, 0), Score: 25, Tetrominoes 27, Cleared lines: 0
# Epoch: 572/3000, Action: (0, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 573/3000, Action: (6, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 574/3000, Action: (4, 1), Score: 29, Tetrominoes 31, Cleared lines: 0
# Epoch: 575/3000, Action: (2, 1), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 576/3000, Action: (2, 2), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 577/3000, Action: (5, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 578/3000, Action: (4, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 579/3000, Action: (4, 0), Score: 30, Tetrominoes 22, Cleared lines: 1
# Epoch: 580/3000, Action: (1, 1), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 581/3000, Action: (4, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 582/3000, Action: (6, 2), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 583/3000, Action: (4, 0), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 584/3000, Action: (3, 2), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 585/3000, Action: (6, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 586/3000, Action: (3, 3), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 587/3000, Action: (4, 0), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 588/3000, Action: (6, 2), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 589/3000, Action: (7, 0), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 590/3000, Action: (1, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 591/3000, Action: (4, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 592/3000, Action: (1, 0), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 593/3000, Action: (0, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 594/3000, Action: (5, 0), Score: 26, Tetrominoes 28, Cleared lines: 0
# Epoch: 595/3000, Action: (5, 1), Score: 38, Tetrominoes 30, Cleared lines: 1
# Epoch: 596/3000, Action: (5, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 597/3000, Action: (3, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 598/3000, Action: (4, 3), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 599/3000, Action: (5, 1), Score: 25, Tetrominoes 27, Cleared lines: 0
# Epoch: 600/3000, Action: (5, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 601/3000, Action: (3, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 602/3000, Action: (3, 0), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 603/3000, Action: (4, 0), Score: 26, Tetrominoes 28, Cleared lines: 0
# Epoch: 604/3000, Action: (3, 2), Score: 25, Tetrominoes 27, Cleared lines: 0
# Epoch: 605/3000, Action: (5, 0), Score: 36, Tetrominoes 28, Cleared lines: 1
# Epoch: 606/3000, Action: (5, 0), Score: 38, Tetrominoes 30, Cleared lines: 1
# Epoch: 607/3000, Action: (2, 0), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 608/3000, Action: (3, 3), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 609/3000, Action: (4, 0), Score: 31, Tetrominoes 33, Cleared lines: 0
# Epoch: 610/3000, Action: (5, 0), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 611/3000, Action: (7, 1), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 612/3000, Action: (4, 1), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 613/3000, Action: (6, 1), Score: 37, Tetrominoes 29, Cleared lines: 1
# Epoch: 614/3000, Action: (4, 0), Score: 28, Tetrominoes 30, Cleared lines: 0
# Epoch: 615/3000, Action: (1, 1), Score: 30, Tetrominoes 32, Cleared lines: 0
# Epoch: 616/3000, Action: (4, 0), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 617/3000, Action: (8, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 618/3000, Action: (4, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 619/3000, Action: (4, 2), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 620/3000, Action: (2, 0), Score: 28, Tetrominoes 30, Cleared lines: 0
# Epoch: 621/3000, Action: (5, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 622/3000, Action: (2, 2), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 623/3000, Action: (2, 1), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 624/3000, Action: (5, 3), Score: 24, Tetrominoes 26, Cleared lines: 0
# ...
# Epoch: 2466/3000, Action: (2, 0), Score: 28, Tetrominoes 30, Cleared lines: 0
# Epoch:
# Epoch: 2603/3000, Action: (9, 1), Score: 34869, Tetrominoes 4121, Cleared lines: 1633
# Epoch: 2604/3000, Action: (4, 1), Score: 76422, Tetrominoes 9324, Cleared lines: 3714
# Epoch: 2605/3000, Action: (0, 1), Score: 286293, Tetrominoes 36075, Cleared lines: 14416
# Epoch: 2606/3000, Action: (4, 1), Score: 46546, Tetrominoes 6008, Cleared lines: 2388
# Epoch: 2607/3000, Action: (0, 1), Score: 325412, Tetrominoes 40434, Cleared lines: 16160
# Epoch: 2608/3000, Action: (3, 0), Score: 165058, Tetrominoes 19820, Cleared lines: 7914
# Epoch: 2609/3000, Action: (3, 1), Score: 54405, Tetrominoes 6087, Cleared lines: 2420
# Epoch: 2610/3000, Action: (0, 3), Score: 42272, Tetrominoes 4504, Cleared lines: 1789
# Epoch: 2611/3000, Action: (3, 1), Score: 1491, Tetrominoes 183, Cleared lines: 59
# Epoch: 2612/3000, Action: (0, 0), Score: 215, Tetrominoes 67, Cleared lines: 13
# Epoch: 2613/3000, Action: (5, 1), Score: 58, Tetrominoes 40, Cleared lines: 2
# Epoch: 2614/3000, Action: (0, 3), Score: 30, Tetrominoes 32, Cleared lines: 0
# Epoch: 2615/3000, Action: (1, 0), Score: 30, Tetrominoes 32, Cleared lines: 0
# Epoch: 2616/3000, Action: (4, 1), Score: 28, Tetrominoes 30, Cleared lines: 0
# Epoch: 2617/3000, Action: (0, 3), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 2618/3000, Action: (1, 0), Score: 32, Tetrominoes 34, Cleared lines: 0
# Epoch: 2619/3000, Action: (5, 0), Score: 36, Tetrominoes 38, Cleared lines: 0
# Epoch: 2620/3000, Action: (3, 0), Score: 34, Tetrominoes 36, Cleared lines: 0
# Epoch: 2621/3000, Action: (4, 1), Score: 35, Tetrominoes 37, Cleared lines: 0
# Epoch: 2622/3000, Action: (0, 0), Score: 27, Tetrominoes 29, Cleared lines: 0
# Epoch: 2623/3000, Action: (0, 1), Score: 27, Tetrominoes 29, Cleared lines: 0
# Epoch: 2624/3000, Action: (3, 0), Score: 33, Tetrominoes 35, Cleared lines: 0
# Epoch: 2625/3000, Action: (4, 3), Score: 33, Tetrominoes 35, Cleared lines: 0
# Epoch: 2626/3000, Action: (0, 0), Score: 34, Tetrominoes 36, Cleared lines: 0
# Epoch: 2627/3000, Action: (1, 1), Score: 31, Tetrominoes 33, Cleared lines: 0
# Epoch: 2628/3000, Action: (8, 0), Score: 35, Tetrominoes 37, Cleared lines: 0
# Epoch: 2629/3000, Action: (0, 1), Score: 28, Tetrominoes 30, Cleared lines: 0
# Epoch: 2630/3000, Action: (8, 1), Score: 28, Tetrominoes 30, Cleared lines: 0
# Epoch: 2631/3000, Action: (0, 0), Score: 30, Tetrominoes 32, Cleared lines: 0
# Epoch: 2632/3000, Action: (3, 0), Score: 27, Tetrominoes 29, Cleared lines: 0
# Epoch: 2633/3000, Action: (5, 0), Score: 28, Tetrominoes 30, Cleared lines: 0
# Epoch: 2634/3000, Action: (0, 1), Score: 26, Tetrominoes 28, Cleared lines: 0
# Epoch: 2635/3000, Action: (3, 0), Score: 29, Tetrominoes 31, Cleared lines: 0
# Epoch: 2636/3000, Action: (5, 1), Score: 35, Tetrominoes 37, Cleared lines: 0
# Epoch: 2637/3000, Action: (3, 3), Score: 33, Tetrominoes 35, Cleared lines: 0
# Epoch: 2638/3000, Action: (0, 0), Score: 29, Tetrominoes 31, Cleared lines: 0
# Epoch: 2639/3000, Action: (0, 0), Score: 30, Tetrominoes 32, Cleared lines: 0
# Epoch: 2640/3000, Action: (1, 1), Score: 30, Tetrominoes 32, Cleared lines: 0
# Epoch: 2641/3000, Action: (0, 0), Score: 57, Tetrominoes 39, Cleared lines: 2
# Epoch: 2642/3000, Action: (5, 0), Score: 31, Tetrominoes 33, Cleared lines: 0
# Epoch: 2643/3000, Action: (0, 1), Score: 92, Tetrominoes 44, Cleared lines: 5
# Epoch: 2644/3000, Action: (1, 1), Score: 66, Tetrominoes 38, Cleared lines: 3
# Epoch: 2645/3000, Action: (1, 1), Score: 104212, Tetrominoes 10844, Cleared lines: 4325
# Epoch: 2646/3000, Action: (0, 1), Score: 604214, Tetrominoes 71056, Cleared lines: 28410
# Epoch: 2647/3000, Action: (5, 0), Score: 77017, Tetrominoes 9419, Cleared lines: 3754
# Epoch: 2648/3000, Action: (5, 1), Score: 671164, Tetrominoes 85586, Cleared lines: 34222
# Epoch: 2649/3000, Action: (3, 0), Score: 237389, Tetrominoes 30951, Cleared lines: 12366
# Epoch: 2650/3000, Action: (0, 1), Score: 4293852, Tetrominoes 569724, Cleared lines: 227877
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 agent_tetris = train()
#
# Cell In[4], line 16, in train()
#      13 epoch = 0
#      15 while epoch < NUM_EPOCHS:
# ---> 16     next_steps = env.get_next_states()
#      17     # Epsilon Greedy
#      18     epsilon = FINAL_EPSILON + (max(NUM_DECAY_EPOCHS - epoch, 0) *
#      19                                (INITIAL_EPSILON - FINAL_EPSILON) / NUM_DECAY_EPOCHS)
#
# File c:\Users\rohan\Desktop\175\Tetris-AI\tetris.py:192, in Tetris.get_next_states(self)
#     190         self.truncate(piece, pos)
#     191         board = self.store(piece, pos)
# --> 192         states[(x, i)] = self.get_state_properties(board)
#     193     curr_piece = self.rotate(curr_piece)
#     194 return states
#
# File c:\Users\rohan\Desktop\175\Tetris-AI\tetris.py:92, in Tetris.get_state_properties(self, board)
#      89 holes = self.get_holes(board)
#      90 bumpiness, height = self.get_bumpiness_and_height(board)
# ---> 92 return torch.FloatTensor([lines_cleared, holes, bumpiness, height])
#
# KeyboardInterrupt:

# %% [markdown]
# ## Record a Single Game with Trained Agent

# %%
# Constants
WIDTH = 10  # Width of the board
HEIGHT = 20  # Height of the board
BLOCK_SIZE = 30  # Block size when rendering
FPS = 100  # Frames per second for video output

OUTPUT_VIDEO = "demo.mp4"

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

agent_tetris = DQN().to(DEVICE)
agent_tetris.load_state_dict(torch.load("policy_net.pth"))
# Out:
# C:\Users\rohan\AppData\Local\Temp\ipykernel_27236\365448699.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   agent_tetris.load_state_dict(torch.load("linear_policy_net.pth"))
# <All keys matched successfully>

# %%
def record_game(model):
    """
    Test the Deep Q Network by playing Tetris and rendering the output as a video.
    """
    # Set random seeds for reproducibility
    torch.manual_seed(123)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(123)

    model.eval()  # Set the model to evaluation mode

    env = Tetris(width=WIDTH, height=HEIGHT, block_size=BLOCK_SIZE)
    env.reset()
    model.to(DEVICE)

    video_size = (int(1.5 * WIDTH * BLOCK_SIZE), HEIGHT * BLOCK_SIZE)
    video_writer = cv2.VideoWriter(OUTPUT_VIDEO, cv2.VideoWriter_fourcc(*"mp4v"), FPS, video_size)

    blocks = 0

    while True:
        next_steps = env.get_next_states()
        next_actions, next_states = zip(*next_steps.items())
        next_states = torch.stack(next_states).to(DEVICE)

        with torch.no_grad():
            predictions = model(next_states)[:, 0]
        best_action_index = torch.argmax(predictions).item()
        action = next_actions[best_action_index]

        _, done = env.step(action, render=True, video=video_writer)

        blocks += 1
        #print(blocks)

        if done or blocks > 1000:
            video_writer.release()
            print("Game over. Video saved to:", OUTPUT_VIDEO)
            break
    cv2.destroyAllWindows()

# %%
record_game(agent_tetris)
# Out:
# Game over. Video saved to: demo.mp4
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Get Agent Stats for 20 Games

# %%
FPS = 300
def evaluate_model(model, num_games=10):
    model.eval()
    env = Tetris(width=WIDTH, height=HEIGHT, block_size=BLOCK_SIZE)

    total_score = 0
    total_tetrominoes = 0
    total_lines_cleared = 0

    for game in range(num_games):
        _ = env.reset().to(DEVICE)
        game_score = 0
        game_tetrominoes = 0
        game_lines_cleared = 0

        while True:
            next_steps = env.get_next_states()
            next_actions, next_states = zip(*next_steps.items())
            next_states = torch.stack(next_states).to(DEVICE)

            with torch.no_grad():
                predictions = model(next_states)[:, 0]
            best_action_index = torch.argmax(predictions).item()
            action = next_actions[best_action_index]

            _, done = env.step(action,render=False)

            game_score = env.score
            game_tetrominoes = env.tetrominoes
            game_lines_cleared = env.cleared_lines

            if done:
                break

        # Accumulate totals
        total_score += game_score
        total_tetrominoes += game_tetrominoes
        total_lines_cleared += game_lines_cleared

        print(f"Game {game + 1}/{num_games} - Score: {game_score}, Tetrominoes: {game_tetrominoes}, Lines Cleared: {game_lines_cleared}")

    # Calculate averages
    avg_score = total_score / num_games
    avg_tetrominoes = total_tetrominoes / num_games
    avg_lines_cleared = total_lines_cleared / num_games

    print(f"\nEvaluation Results:")
    print(f"Average Score: {avg_score}")
    print(f"Average Tetrominoes: {avg_tetrominoes}")
    print(f"Average Lines Cleared: {avg_lines_cleared}")

    return avg_score, avg_tetrominoes, avg_lines_cleared

# %%
avg_score, avg_tetrominoes, avg_lines_cleared = evaluate_model(agent_tetris)
# Out:
# Game 1/10 - Score: 30600, Tetrominoes: 6142, Lines Cleared: 2446
# Game 2/10 - Score: 160896, Tetrominoes: 32208, Lines Cleared: 12869
# Game 3/10 - Score: 511004, Tetrominoes: 102226, Lines Cleared: 40878
# Game 4/10 - Score: 403818, Tetrominoes: 80790, Lines Cleared: 32303
# Game 5/10 - Score: 228705, Tetrominoes: 45767, Lines Cleared: 18294
# Game 6/10 - Score: 689743, Tetrominoes: 137975, Lines Cleared: 55177
# Game 7/10 - Score: 971629, Tetrominoes: 194351, Lines Cleared: 77728
# Game 8/10 - Score: 336717, Tetrominoes: 67369, Lines Cleared: 26935
# Game 9/10 - Score: 134862, Tetrominoes: 27004, Lines Cleared: 10786
# Game 10/10 - Score: 1420347, Tetrominoes: 284099, Lines Cleared: 113625
#
# Evaluation Results:
# Average Score: 488832.1
# Average Tetrominoes: 97793.1
# Average Lines Cleared: 39104.1
