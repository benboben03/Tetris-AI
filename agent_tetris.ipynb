# %%
from random import random, randint, sample

import numpy as np
import torch
import torch.nn as nn

import cv2
from tetris import Tetris
from collections import deque

# %% [markdown]
# ## Deep Q Learning Network

# %%
class DQN(nn.Module):
    def __init__(self):
        super(DQN, self).__init__()

        self.conv1 = nn.Sequential(nn.Linear(4, 64), nn.ReLU(inplace=True))
        self.conv2 = nn.Sequential(nn.Linear(64, 64), nn.ReLU(inplace=True))
        self.conv3 = nn.Sequential(nn.Linear(64, 1))

        self._create_weights()

    def _create_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)

        return x

# %% [markdown]
# ## Global Constants

# %%
WIDTH = 10  # Width of board
HEIGHT = 20  # Height of board
BLOCK_SIZE = 30  # Block size when rendering
BATCH_SIZE = 512  # High batch size
LEARNING_RATE = 1e-3
GAMMA = 0.99
INITIAL_EPSILON = 1.0
FINAL_EPSILON = 1e-3
NUM_DECAY_EPOCHS = 1350
NUM_EPOCHS = 2000
SAVE_INTERVAL = 500
REPLAY_MEMORY_SIZE = 22000

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cpu')

# %% [markdown]
# ## Training Loop Using Epsilon Greedy and Experience Replay

# %%
def train():
    torch.manual_seed(42)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(42)

    env = Tetris(width=WIDTH, height=HEIGHT, block_size=BLOCK_SIZE)
    model = DQN().to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
    criterion = nn.MSELoss()

    state = env.reset().to(DEVICE)
    replay_memory = deque(maxlen=REPLAY_MEMORY_SIZE)
    epoch = 0

    while epoch < NUM_EPOCHS:
        next_steps = env.get_next_states()
        # Exploration or exploitation
        epsilon = FINAL_EPSILON + (max(NUM_DECAY_EPOCHS - epoch, 0) * 
                                   (INITIAL_EPSILON - FINAL_EPSILON) / NUM_DECAY_EPOCHS)
        next_actions, next_states = zip(*next_steps.items())
        next_states = torch.stack(next_states).to(DEVICE)

        model.eval()
        with torch.no_grad():
            predictions = model(next_states)[:, 0]
        model.train()

        if random() <= epsilon:
            index = randint(0, len(next_steps) - 1)
        else:
            index = torch.argmax(predictions).item()

        next_state = next_states[index, :]
        action = next_actions[index]

        reward, done = env.step(action, render=True)
        next_state = next_state.to(DEVICE)
        replay_memory.append([state, reward, next_state, done])

        if done:
            final_score = env.score
            final_tetrominoes = env.tetrominoes
            final_cleared_lines = env.cleared_lines
            state = env.reset().to(DEVICE)
        else:
            state = next_state
            continue

        if len(replay_memory) < REPLAY_MEMORY_SIZE / 10:
            continue

        epoch += 1
        batch = sample(replay_memory, min(len(replay_memory), BATCH_SIZE))
        state_batch, reward_batch, next_state_batch, done_batch = zip(*batch)
        state_batch = torch.stack(tuple(state for state in state_batch)).to(DEVICE)
        reward_batch = torch.from_numpy(np.array(reward_batch, dtype=np.float32)[:, None]).to(DEVICE)
        next_state_batch = torch.stack(tuple(state for state in next_state_batch)).to(DEVICE)

        q_values = model(state_batch)
        model.eval()
        with torch.no_grad():
            next_prediction_batch = model(next_state_batch)
        model.train()

        y_batch = torch.cat(
            tuple(reward if done else reward + GAMMA * prediction for reward, done, prediction in
                  zip(reward_batch, done_batch, next_prediction_batch)))[:, None]

        optimizer.zero_grad()
        loss = criterion(q_values, y_batch)
        loss.backward()
        optimizer.step()

        print("Epoch: {}/{}, Action: {}, Score: {}, Tetrominoes {}, Cleared lines: {}".format(
            epoch,
            NUM_EPOCHS,
            action,
            final_score,
            final_tetrominoes,
            final_cleared_lines))

        if epoch > 0 and epoch % SAVE_INTERVAL == 0:
            torch.save(model.state_dict(), "policy_net.pth")

    torch.save(model.state_dict(), "policy_net.pth")
    return model

# %%
agent_tetris = train()
# Out:
# 2024-11-30 14:45:10.590 python[12488:354023] +[IMKClient subclass]: chose IMKClient_Modern
# 2024-11-30 14:45:10.590 python[12488:354023] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# Epoch: 1/2000, Action: (5, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 2/2000, Action: (5, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 3/2000, Action: (7, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 4/2000, Action: (6, 3), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 5/2000, Action: (2, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 6/2000, Action: (7, 0), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 7/2000, Action: (8, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 8/2000, Action: (5, 1), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch: 9/2000, Action: (3, 1), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 10/2000, Action: (5, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 11/2000, Action: (6, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 12/2000, Action: (4, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 13/2000, Action: (5, 2), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 14/2000, Action: (8, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 15/2000, Action: (6, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 16/2000, Action: (0, 3), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 17/2000, Action: (2, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 18/2000, Action: (2, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 19/2000, Action: (0, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 20/2000, Action: (5, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 21/2000, Action: (4, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 22/2000, Action: (6, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 23/2000, Action: (9, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 24/2000, Action: (6, 3), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 25/2000, Action: (5, 2), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 26/2000, Action: (4, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 27/2000, Action: (6, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 28/2000, Action: (4, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 29/2000, Action: (0, 3), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 30/2000, Action: (7, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 31/2000, Action: (6, 0), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 32/2000, Action: (6, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 33/2000, Action: (6, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 34/2000, Action: (4, 1), Score: 35, Tetrominoes 27, Cleared lines: 1
# Epoch: 35/2000, Action: (8, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 36/2000, Action: (2, 3), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 37/2000, Action: (4, 2), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 38/2000, Action: (6, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 39/2000, Action: (8, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 40/2000, Action: (1, 0), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 41/2000, Action: (5, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 42/2000, Action: (6, 0), Score: 31, Tetrominoes 23, Cleared lines: 1
# Epoch: 43/2000, Action: (4, 0), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 44/2000, Action: (2, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 45/2000, Action: (4, 2), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 46/2000, Action: (7, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 47/2000, Action: (3, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 48/2000, Action: (0, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 49/2000, Action: (4, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 50/2000, Action: (4, 3), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 51/2000, Action: (6, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 52/2000, Action: (3, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 53/2000, Action: (3, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 54/2000, Action: (0, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 55/2000, Action: (6, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 56/2000, Action: (0, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 57/2000, Action: (2, 2), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 58/2000, Action: (4, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 59/2000, Action: (5, 3), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 60/2000, Action: (0, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 61/2000, Action: (3, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 62/2000, Action: (3, 0), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 63/2000, Action: (4, 3), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 64/2000, Action: (4, 0), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 65/2000, Action: (0, 3), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 66/2000, Action: (4, 1), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 67/2000, Action: (5, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 68/2000, Action: (6, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 69/2000, Action: (4, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 70/2000, Action: (5, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 71/2000, Action: (3, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 72/2000, Action: (5, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 73/2000, Action: (2, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 74/2000, Action: (4, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 75/2000, Action: (5, 1), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 76/2000, Action: (6, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 77/2000, Action: (1, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 78/2000, Action: (6, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 79/2000, Action: (3, 2), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 80/2000, Action: (4, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 81/2000, Action: (2, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 82/2000, Action: (0, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 83/2000, Action: (4, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 84/2000, Action: (4, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 85/2000, Action: (4, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 86/2000, Action: (4, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 87/2000, Action: (4, 3), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 88/2000, Action: (3, 3), Score: 8, Tetrominoes 10, Cleared lines: 0
# Epoch: 89/2000, Action: (5, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 90/2000, Action: (4, 3), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 91/2000, Action: (5, 2), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 92/2000, Action: (6, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 93/2000, Action: (1, 0), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 94/2000, Action: (7, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 95/2000, Action: (5, 2), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 96/2000, Action: (3, 1), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 97/2000, Action: (1, 0), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 98/2000, Action: (4, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 99/2000, Action: (6, 1), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 100/2000, Action: (4, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 101/2000, Action: (3, 3), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 102/2000, Action: (0, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 103/2000, Action: (6, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 104/2000, Action: (2, 2), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 105/2000, Action: (5, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 106/2000, Action: (1, 2), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 107/2000, Action: (5, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 108/2000, Action: (3, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 109/2000, Action: (6, 1), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 110/2000, Action: (2, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 111/2000, Action: (3, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 112/2000, Action: (4, 2), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 113/2000, Action: (4, 0), Score: 9, Tetrominoes 11, Cleared lines: 0
# Epoch: 114/2000, Action: (1, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 115/2000, Action: (5, 0), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 116/2000, Action: (5, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 117/2000, Action: (7, 0), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 118/2000, Action: (4, 0), Score: 7, Tetrominoes 9, Cleared lines: 0
# Epoch: 119/2000, Action: (0, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 120/2000, Action: (0, 1), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 121/2000, Action: (5, 0), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 122/2000, Action: (8, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 123/2000, Action: (4, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 124/2000, Action: (6, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 125/2000, Action: (3, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 126/2000, Action: (6, 2), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 127/2000, Action: (3, 2), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 128/2000, Action: (5, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 129/2000, Action: (2, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 130/2000, Action: (6, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 131/2000, Action: (4, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 132/2000, Action: (4, 1), Score: 8, Tetrominoes 10, Cleared lines: 0
# Epoch: 133/2000, Action: (3, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 134/2000, Action: (2, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 135/2000, Action: (5, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 136/2000, Action: (8, 1), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 137/2000, Action: (7, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 138/2000, Action: (6, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 139/2000, Action: (3, 3), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 140/2000, Action: (5, 3), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 141/2000, Action: (4, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 142/2000, Action: (3, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 143/2000, Action: (1, 1), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 144/2000, Action: (5, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 145/2000, Action: (4, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 146/2000, Action: (6, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 147/2000, Action: (5, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 148/2000, Action: (3, 3), Score: 7, Tetrominoes 9, Cleared lines: 0
# Epoch: 149/2000, Action: (3, 0), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 150/2000, Action: (2, 2), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 151/2000, Action: (2, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 152/2000, Action: (8, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 153/2000, Action: (3, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 154/2000, Action: (1, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 155/2000, Action: (6, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 156/2000, Action: (5, 3), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 157/2000, Action: (7, 3), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 158/2000, Action: (5, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 159/2000, Action: (6, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 160/2000, Action: (3, 3), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 161/2000, Action: (1, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 162/2000, Action: (0, 3), Score: 27, Tetrominoes 29, Cleared lines: 0
# Epoch: 163/2000, Action: (4, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 164/2000, Action: (6, 1), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 165/2000, Action: (7, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 166/2000, Action: (1, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 167/2000, Action: (4, 2), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 168/2000, Action: (2, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 169/2000, Action: (6, 3), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 170/2000, Action: (4, 0), Score: 8, Tetrominoes 10, Cleared lines: 0
# Epoch: 171/2000, Action: (3, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 172/2000, Action: (3, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 173/2000, Action: (3, 3), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 174/2000, Action: (4, 1), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch: 175/2000, Action: (1, 1), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 176/2000, Action: (2, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 177/2000, Action: (5, 2), Score: 8, Tetrominoes 10, Cleared lines: 0
# Epoch: 178/2000, Action: (1, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 179/2000, Action: (4, 0), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch: 180/2000, Action: (5, 3), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 181/2000, Action: (1, 1), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 182/2000, Action: (6, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 183/2000, Action: (5, 3), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 184/2000, Action: (4, 0), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 185/2000, Action: (5, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 186/2000, Action: (4, 1), Score: 9, Tetrominoes 11, Cleared lines: 0
# Epoch: 187/2000, Action: (2, 2), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 188/2000, Action: (3, 3), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 189/2000, Action: (4, 1), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch: 190/2000, Action: (0, 3), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 191/2000, Action: (3, 0), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch: 192/2000, Action: (7, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 193/2000, Action: (2, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 194/2000, Action: (0, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 195/2000, Action: (5, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 196/2000, Action: (6, 3), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 197/2000, Action: (5, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 198/2000, Action: (4, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 199/2000, Action: (6, 2), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 200/2000, Action: (6, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 201/2000, Action: (0, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 202/2000, Action: (4, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 203/2000, Action: (0, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 204/2000, Action: (3, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 205/2000, Action: (2, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 206/2000, Action: (7, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 207/2000, Action: (2, 0), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 208/2000, Action: (1, 0), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 209/2000, Action: (2, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 210/2000, Action: (4, 3), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 211/2000, Action: (4, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 212/2000, Action: (2, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 213/2000, Action: (5, 0), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 214/2000, Action: (5, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 215/2000, Action: (1, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 216/2000, Action: (5, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 217/2000, Action: (2, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 218/2000, Action: (5, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 219/2000, Action: (4, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 220/2000, Action: (4, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 221/2000, Action: (0, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 222/2000, Action: (6, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 223/2000, Action: (4, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 224/2000, Action: (1, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 225/2000, Action: (2, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 226/2000, Action: (0, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 227/2000, Action: (1, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 228/2000, Action: (0, 1), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch: 229/2000, Action: (2, 0), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 230/2000, Action: (3, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 231/2000, Action: (1, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 232/2000, Action: (3, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 233/2000, Action: (3, 2), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 234/2000, Action: (5, 1), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch: 235/2000, Action: (6, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 236/2000, Action: (4, 1), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 237/2000, Action: (3, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 238/2000, Action: (6, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 239/2000, Action: (5, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 240/2000, Action: (5, 0), Score: 25, Tetrominoes 27, Cleared lines: 0
# Epoch: 241/2000, Action: (3, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 242/2000, Action: (4, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 243/2000, Action: (4, 3), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 244/2000, Action: (6, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 245/2000, Action: (3, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 246/2000, Action: (2, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 247/2000, Action: (5, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 248/2000, Action: (5, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 249/2000, Action: (3, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 250/2000, Action: (3, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 251/2000, Action: (8, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 252/2000, Action: (2, 3), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 253/2000, Action: (4, 1), Score: 8, Tetrominoes 10, Cleared lines: 0
# Epoch: 254/2000, Action: (5, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 255/2000, Action: (3, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 256/2000, Action: (4, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 257/2000, Action: (4, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 258/2000, Action: (2, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 259/2000, Action: (3, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 260/2000, Action: (2, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 261/2000, Action: (5, 2), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 262/2000, Action: (4, 2), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 263/2000, Action: (4, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 264/2000, Action: (3, 1), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch: 265/2000, Action: (3, 1), Score: 32, Tetrominoes 24, Cleared lines: 1
# Epoch: 266/2000, Action: (5, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 267/2000, Action: (2, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 268/2000, Action: (8, 1), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 269/2000, Action: (3, 0), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 270/2000, Action: (5, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 271/2000, Action: (2, 2), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch: 272/2000, Action: (6, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 273/2000, Action: (5, 0), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 274/2000, Action: (0, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 275/2000, Action: (4, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 276/2000, Action: (4, 2), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 277/2000, Action: (4, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 278/2000, Action: (9, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 279/2000, Action: (6, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 280/2000, Action: (6, 3), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 281/2000, Action: (4, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 282/2000, Action: (6, 3), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 283/2000, Action: (2, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 284/2000, Action: (2, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 285/2000, Action: (4, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 286/2000, Action: (4, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 287/2000, Action: (5, 1), Score: 25, Tetrominoes 27, Cleared lines: 0
# Epoch: 288/2000, Action: (4, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 289/2000, Action: (2, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 290/2000, Action: (3, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 291/2000, Action: (5, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 292/2000, Action: (5, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 293/2000, Action: (6, 0), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 294/2000, Action: (2, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 295/2000, Action: (7, 3), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 296/2000, Action: (5, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 297/2000, Action: (5, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 298/2000, Action: (1, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 299/2000, Action: (0, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 300/2000, Action: (0, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 301/2000, Action: (3, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 302/2000, Action: (2, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 303/2000, Action: (3, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 304/2000, Action: (4, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 305/2000, Action: (6, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 306/2000, Action: (6, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 307/2000, Action: (0, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 308/2000, Action: (6, 0), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 309/2000, Action: (0, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 310/2000, Action: (2, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 311/2000, Action: (0, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 312/2000, Action: (7, 3), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 313/2000, Action: (6, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 314/2000, Action: (6, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 315/2000, Action: (4, 3), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 316/2000, Action: (4, 2), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 317/2000, Action: (3, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 318/2000, Action: (3, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 319/2000, Action: (4, 0), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch: 320/2000, Action: (5, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 321/2000, Action: (4, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 322/2000, Action: (4, 3), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 323/2000, Action: (4, 2), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 324/2000, Action: (5, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 325/2000, Action: (6, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 326/2000, Action: (6, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 327/2000, Action: (4, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 328/2000, Action: (1, 0), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 329/2000, Action: (5, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 330/2000, Action: (2, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 331/2000, Action: (4, 0), Score: 25, Tetrominoes 27, Cleared lines: 0
# Epoch: 332/2000, Action: (1, 0), Score: 26, Tetrominoes 28, Cleared lines: 0
# Epoch: 333/2000, Action: (3, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 334/2000, Action: (3, 3), Score: 8, Tetrominoes 10, Cleared lines: 0
# Epoch: 335/2000, Action: (4, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 336/2000, Action: (4, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 337/2000, Action: (3, 0), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 338/2000, Action: (2, 2), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 339/2000, Action: (4, 1), Score: 30, Tetrominoes 22, Cleared lines: 1
# Epoch: 340/2000, Action: (2, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 341/2000, Action: (4, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 342/2000, Action: (4, 0), Score: 8, Tetrominoes 10, Cleared lines: 0
# Epoch: 343/2000, Action: (1, 2), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 344/2000, Action: (5, 0), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 345/2000, Action: (2, 0), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 346/2000, Action: (5, 0), Score: 39, Tetrominoes 31, Cleared lines: 1
# Epoch: 347/2000, Action: (0, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 348/2000, Action: (5, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 349/2000, Action: (4, 1), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 350/2000, Action: (6, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 351/2000, Action: (2, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 352/2000, Action: (7, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 353/2000, Action: (3, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 354/2000, Action: (4, 2), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 355/2000, Action: (6, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 356/2000, Action: (3, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 357/2000, Action: (4, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 358/2000, Action: (1, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 359/2000, Action: (4, 1), Score: 7, Tetrominoes 9, Cleared lines: 0
# Epoch: 360/2000, Action: (5, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 361/2000, Action: (2, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 362/2000, Action: (4, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 363/2000, Action: (1, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 364/2000, Action: (2, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 365/2000, Action: (2, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 366/2000, Action: (6, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 367/2000, Action: (5, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 368/2000, Action: (1, 3), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 369/2000, Action: (2, 1), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 370/2000, Action: (1, 1), Score: 25, Tetrominoes 17, Cleared lines: 1
# Epoch: 371/2000, Action: (4, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 372/2000, Action: (1, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 373/2000, Action: (5, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 374/2000, Action: (3, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 375/2000, Action: (0, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 376/2000, Action: (2, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 377/2000, Action: (6, 1), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 378/2000, Action: (3, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 379/2000, Action: (2, 2), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 380/2000, Action: (4, 0), Score: 26, Tetrominoes 28, Cleared lines: 0
# Epoch: 381/2000, Action: (4, 3), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 382/2000, Action: (3, 3), Score: 25, Tetrominoes 27, Cleared lines: 0
# Epoch: 383/2000, Action: (4, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 384/2000, Action: (3, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 385/2000, Action: (4, 3), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 386/2000, Action: (3, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 387/2000, Action: (7, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 388/2000, Action: (4, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 389/2000, Action: (4, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 390/2000, Action: (3, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 391/2000, Action: (5, 0), Score: 9, Tetrominoes 11, Cleared lines: 0
# Epoch: 392/2000, Action: (5, 2), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 393/2000, Action: (2, 1), Score: 40, Tetrominoes 32, Cleared lines: 1
# Epoch: 394/2000, Action: (2, 0), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 395/2000, Action: (6, 3), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 396/2000, Action: (2, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 397/2000, Action: (3, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 398/2000, Action: (7, 1), Score: 30, Tetrominoes 32, Cleared lines: 0
# Epoch: 399/2000, Action: (2, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 400/2000, Action: (6, 2), Score: 60, Tetrominoes 22, Cleared lines: 2
# Epoch: 401/2000, Action: (8, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 402/2000, Action: (0, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 403/2000, Action: (4, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 404/2000, Action: (5, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 405/2000, Action: (4, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 406/2000, Action: (4, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 407/2000, Action: (4, 0), Score: 49, Tetrominoes 31, Cleared lines: 2
# Epoch: 408/2000, Action: (3, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 409/2000, Action: (3, 3), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 410/2000, Action: (5, 0), Score: 29, Tetrominoes 31, Cleared lines: 0
# Epoch: 411/2000, Action: (3, 1), Score: 9, Tetrominoes 11, Cleared lines: 0
# Epoch: 412/2000, Action: (5, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 413/2000, Action: (4, 3), Score: 44, Tetrominoes 36, Cleared lines: 1
# Epoch: 414/2000, Action: (3, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 415/2000, Action: (4, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 416/2000, Action: (5, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 417/2000, Action: (5, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 418/2000, Action: (3, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 419/2000, Action: (0, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 420/2000, Action: (5, 1), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 421/2000, Action: (4, 3), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 422/2000, Action: (4, 0), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 423/2000, Action: (5, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 424/2000, Action: (5, 1), Score: 26, Tetrominoes 28, Cleared lines: 0
# Epoch: 425/2000, Action: (5, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 426/2000, Action: (4, 1), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 427/2000, Action: (5, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 428/2000, Action: (8, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 429/2000, Action: (7, 0), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 430/2000, Action: (5, 0), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 431/2000, Action: (4, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 432/2000, Action: (6, 1), Score: 29, Tetrominoes 31, Cleared lines: 0
# Epoch: 433/2000, Action: (2, 0), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 434/2000, Action: (6, 0), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 435/2000, Action: (5, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 436/2000, Action: (2, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 437/2000, Action: (5, 2), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 438/2000, Action: (3, 0), Score: 26, Tetrominoes 28, Cleared lines: 0
# Epoch: 439/2000, Action: (7, 3), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 440/2000, Action: (2, 3), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 441/2000, Action: (3, 3), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 442/2000, Action: (8, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 443/2000, Action: (4, 1), Score: 26, Tetrominoes 28, Cleared lines: 0
# Epoch: 444/2000, Action: (5, 3), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 445/2000, Action: (4, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 446/2000, Action: (4, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 447/2000, Action: (6, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 448/2000, Action: (6, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 449/2000, Action: (3, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 450/2000, Action: (1, 3), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 451/2000, Action: (3, 0), Score: 31, Tetrominoes 33, Cleared lines: 0
# Epoch: 452/2000, Action: (0, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 453/2000, Action: (3, 3), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 454/2000, Action: (5, 3), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 455/2000, Action: (6, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 456/2000, Action: (4, 3), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 457/2000, Action: (4, 3), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 458/2000, Action: (4, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 459/2000, Action: (5, 2), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 460/2000, Action: (3, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 461/2000, Action: (5, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 462/2000, Action: (4, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 463/2000, Action: (2, 2), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 464/2000, Action: (2, 0), Score: 53, Tetrominoes 35, Cleared lines: 2
# Epoch: 465/2000, Action: (2, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 466/2000, Action: (5, 1), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 467/2000, Action: (2, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 468/2000, Action: (2, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 469/2000, Action: (5, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 470/2000, Action: (2, 2), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 471/2000, Action: (3, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 472/2000, Action: (0, 3), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 473/2000, Action: (4, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 474/2000, Action: (5, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 475/2000, Action: (5, 2), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 476/2000, Action: (0, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 477/2000, Action: (4, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 478/2000, Action: (6, 2), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 479/2000, Action: (0, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 480/2000, Action: (3, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 481/2000, Action: (3, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 482/2000, Action: (2, 3), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 483/2000, Action: (6, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 484/2000, Action: (4, 1), Score: 25, Tetrominoes 27, Cleared lines: 0
# Epoch: 485/2000, Action: (4, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 486/2000, Action: (8, 1), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 487/2000, Action: (3, 0), Score: 32, Tetrominoes 24, Cleared lines: 1
# Epoch: 488/2000, Action: (9, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 489/2000, Action: (5, 3), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 490/2000, Action: (4, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 491/2000, Action: (2, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 492/2000, Action: (3, 3), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 493/2000, Action: (3, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 494/2000, Action: (3, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 495/2000, Action: (4, 1), Score: 33, Tetrominoes 25, Cleared lines: 1
# Epoch: 496/2000, Action: (2, 3), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 497/2000, Action: (2, 2), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 498/2000, Action: (4, 1), Score: 25, Tetrominoes 27, Cleared lines: 0
# Epoch: 499/2000, Action: (3, 2), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 500/2000, Action: (0, 0), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 501/2000, Action: (8, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 502/2000, Action: (4, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 503/2000, Action: (2, 0), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 504/2000, Action: (5, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 505/2000, Action: (5, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 506/2000, Action: (2, 0), Score: 27, Tetrominoes 29, Cleared lines: 0
# Epoch: 507/2000, Action: (2, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 508/2000, Action: (3, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 509/2000, Action: (6, 2), Score: 31, Tetrominoes 33, Cleared lines: 0
# Epoch: 510/2000, Action: (4, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 511/2000, Action: (4, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 512/2000, Action: (4, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 513/2000, Action: (3, 0), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 514/2000, Action: (2, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 515/2000, Action: (7, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 516/2000, Action: (0, 1), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 517/2000, Action: (4, 0), Score: 30, Tetrominoes 32, Cleared lines: 0
# Epoch: 518/2000, Action: (5, 0), Score: 8, Tetrominoes 10, Cleared lines: 0
# Epoch: 519/2000, Action: (4, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 520/2000, Action: (5, 1), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 521/2000, Action: (4, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 522/2000, Action: (3, 3), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 523/2000, Action: (6, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 524/2000, Action: (3, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 525/2000, Action: (5, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 526/2000, Action: (4, 3), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 527/2000, Action: (4, 2), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 528/2000, Action: (5, 2), Score: 28, Tetrominoes 30, Cleared lines: 0
# Epoch: 529/2000, Action: (2, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 530/2000, Action: (8, 0), Score: 31, Tetrominoes 23, Cleared lines: 1
# Epoch: 531/2000, Action: (2, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 532/2000, Action: (5, 1), Score: 26, Tetrominoes 28, Cleared lines: 0
# Epoch: 533/2000, Action: (4, 1), Score: 30, Tetrominoes 32, Cleared lines: 0
# Epoch: 534/2000, Action: (0, 3), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 535/2000, Action: (2, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 536/2000, Action: (2, 2), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 537/2000, Action: (4, 1), Score: 43, Tetrominoes 35, Cleared lines: 1
# Epoch: 538/2000, Action: (4, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 539/2000, Action: (3, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 540/2000, Action: (2, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 541/2000, Action: (6, 1), Score: 26, Tetrominoes 28, Cleared lines: 0
# Epoch: 542/2000, Action: (3, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 543/2000, Action: (4, 0), Score: 39, Tetrominoes 31, Cleared lines: 1
# Epoch: 544/2000, Action: (5, 3), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 545/2000, Action: (6, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 546/2000, Action: (4, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 547/2000, Action: (0, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 548/2000, Action: (6, 1), Score: 29, Tetrominoes 21, Cleared lines: 1
# Epoch: 549/2000, Action: (0, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 550/2000, Action: (6, 0), Score: 26, Tetrominoes 28, Cleared lines: 0
# Epoch: 551/2000, Action: (6, 0), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 552/2000, Action: (4, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 553/2000, Action: (5, 1), Score: 25, Tetrominoes 27, Cleared lines: 0
# Epoch: 554/2000, Action: (5, 1), Score: 31, Tetrominoes 33, Cleared lines: 0
# Epoch: 555/2000, Action: (0, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 556/2000, Action: (0, 2), Score: 32, Tetrominoes 34, Cleared lines: 0
# Epoch: 557/2000, Action: (1, 0), Score: 29, Tetrominoes 21, Cleared lines: 1
# Epoch: 558/2000, Action: (4, 1), Score: 28, Tetrominoes 30, Cleared lines: 0
# Epoch: 559/2000, Action: (4, 1), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 560/2000, Action: (5, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 561/2000, Action: (6, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 562/2000, Action: (4, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 563/2000, Action: (0, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 564/2000, Action: (3, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 565/2000, Action: (6, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 566/2000, Action: (0, 3), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 567/2000, Action: (6, 0), Score: 25, Tetrominoes 27, Cleared lines: 0
# Epoch: 568/2000, Action: (0, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 569/2000, Action: (2, 2), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 570/2000, Action: (6, 1), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 571/2000, Action: (3, 1), Score: 34, Tetrominoes 26, Cleared lines: 1
# Epoch: 572/2000, Action: (3, 0), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 573/2000, Action: (5, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 574/2000, Action: (3, 1), Score: 33, Tetrominoes 25, Cleared lines: 1
# Epoch: 575/2000, Action: (3, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 576/2000, Action: (4, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 577/2000, Action: (1, 3), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 578/2000, Action: (7, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 579/2000, Action: (3, 0), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 580/2000, Action: (7, 3), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 581/2000, Action: (8, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 582/2000, Action: (3, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 583/2000, Action: (6, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 584/2000, Action: (0, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 585/2000, Action: (3, 0), Score: 31, Tetrominoes 23, Cleared lines: 1
# Epoch: 586/2000, Action: (2, 1), Score: 27, Tetrominoes 19, Cleared lines: 1
# Epoch: 587/2000, Action: (0, 3), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 588/2000, Action: (0, 3), Score: 32, Tetrominoes 24, Cleared lines: 1
# Epoch: 589/2000, Action: (6, 0), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 590/2000, Action: (3, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 591/2000, Action: (3, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 592/2000, Action: (3, 3), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 593/2000, Action: (0, 1), Score: 34, Tetrominoes 26, Cleared lines: 1
# Epoch: 594/2000, Action: (5, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 595/2000, Action: (3, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 596/2000, Action: (5, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 597/2000, Action: (4, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 598/2000, Action: (2, 2), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 599/2000, Action: (4, 3), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 600/2000, Action: (7, 0), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 601/2000, Action: (2, 0), Score: 38, Tetrominoes 30, Cleared lines: 1
# Epoch: 602/2000, Action: (8, 1), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 603/2000, Action: (5, 1), Score: 26, Tetrominoes 28, Cleared lines: 0
# Epoch: 604/2000, Action: (4, 1), Score: 28, Tetrominoes 30, Cleared lines: 0
# Epoch: 605/2000, Action: (0, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 606/2000, Action: (2, 0), Score: 31, Tetrominoes 33, Cleared lines: 0
# Epoch: 607/2000, Action: (2, 0), Score: 51, Tetrominoes 33, Cleared lines: 2

# %% [markdown]
# ## Record a Single Game with Trained Agent

# %%
# Constants
WIDTH = 10  # Width of the board
HEIGHT = 20  # Height of the board
BLOCK_SIZE = 30  # Block size when rendering
FPS = 100  # Frames per second for video output

OUTPUT_VIDEO = "base_demo.mp4"

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

agent_tetris = DQN().to(DEVICE)
agent_tetris.load_state_dict(torch.load("policy_net.pth"))
# Out:
# C:\Users\rohan\AppData\Local\Temp\ipykernel_27192\4281655833.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   agent_tetris.load_state_dict(torch.load("policy_net.pth"))
# <All keys matched successfully>

# %%
def record_game(model):
    """
    Test the Deep Q Network by playing Tetris and rendering the output as a video.
    """
    # Set random seeds for reproducibility
    torch.manual_seed(123)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(123)

    model.eval()  # Set the model to evaluation mode

    env = Tetris(width=WIDTH, height=HEIGHT, block_size=BLOCK_SIZE)
    env.reset()
    model.to(DEVICE)

    video_size = (int(1.5 * WIDTH * BLOCK_SIZE), HEIGHT * BLOCK_SIZE)
    video_writer = cv2.VideoWriter(OUTPUT_VIDEO, cv2.VideoWriter_fourcc(*"mp4v"), FPS, video_size)

    while True:
        next_steps = env.get_next_states()
        next_actions, next_states = zip(*next_steps.items())
        next_states = torch.stack(next_states).to(DEVICE)

        with torch.no_grad():
            predictions = model(next_states)[:, 0]
        best_action_index = torch.argmax(predictions).item()
        action = next_actions[best_action_index]

        _, done = env.step(action, render=True, video=video_writer)

        if done:
            video_writer.release()
            print("Game over. Video saved to:", OUTPUT_VIDEO)
            break
    cv2.destroyAllWindows()

# %%
record_game(agent_tetris)
# Out:
# Game over. Video saved to: base_demo.mp4

# %% [markdown]
# ## Get Agent Stats for 20 Games

# %%
FPS = 300
def evaluate_model(model, num_games=20):
    """
    Evaluate the performance of a trained model over a specified number of games.
    
    Args:
        model (torch.nn.Module): The trained Deep Q-Network model.
        num_games (int): Number of games to run for evaluation.
    
    Returns:
        tuple: Averages of (score, tetrominoes, lines cleared) over the games.
    """
    model.eval()  # Ensure the model is in evaluation mode
    env = Tetris(width=WIDTH, height=HEIGHT, block_size=BLOCK_SIZE)

    total_score = 0
    total_tetrominoes = 0
    total_lines_cleared = 0

    for game in range(num_games):
        state = env.reset().to(DEVICE)
        game_score = 0
        game_tetrominoes = 0
        game_lines_cleared = 0

        while True:
            # Get possible next states
            next_steps = env.get_next_states()
            next_actions, next_states = zip(*next_steps.items())
            next_states = torch.stack(next_states).to(DEVICE)

            # Predict the best action
            with torch.no_grad():
                predictions = model(next_states)[:, 0]
            best_action_index = torch.argmax(predictions).item()
            action = next_actions[best_action_index]

            # Perform the action in the environment
            _, done = env.step(action)

            # Update game statistics
            game_score = env.score
            game_tetrominoes = env.tetrominoes
            game_lines_cleared = env.cleared_lines

            if done:
                break

        # Accumulate totals
        total_score += game_score
        total_tetrominoes += game_tetrominoes
        total_lines_cleared += game_lines_cleared

        #print(f"Game {game + 1}/{num_games} - Score: {game_score}, Tetrominoes: {game_tetrominoes}, Lines Cleared: {game_lines_cleared}")

    # Calculate averages
    avg_score = total_score / num_games
    avg_tetrominoes = total_tetrominoes / num_games
    avg_lines_cleared = total_lines_cleared / num_games

    print(f"\nEvaluation Results:")
    print(f"Average Score: {avg_score}")
    print(f"Average Tetrominoes: {avg_tetrominoes}")
    print(f"Average Lines Cleared: {avg_lines_cleared}")

    return avg_score, avg_tetrominoes, avg_lines_cleared

# %%
avg_score, avg_tetrominoes, avg_lines_cleared = evaluate_model(agent_tetris)
# Out:
# Game 1/20 - Score: 36, Tetrominoes: 38, Lines Cleared: 0
# Game 2/20 - Score: 32, Tetrominoes: 34, Lines Cleared: 0
# Game 3/20 - Score: 29, Tetrominoes: 31, Lines Cleared: 0
# Game 4/20 - Score: 31, Tetrominoes: 33, Lines Cleared: 0
# Game 5/20 - Score: 28, Tetrominoes: 30, Lines Cleared: 0
# Game 6/20 - Score: 30, Tetrominoes: 32, Lines Cleared: 0
# Game 7/20 - Score: 36, Tetrominoes: 38, Lines Cleared: 0
# Game 8/20 - Score: 33, Tetrominoes: 35, Lines Cleared: 0
# Game 9/20 - Score: 35, Tetrominoes: 37, Lines Cleared: 0
# Game 10/20 - Score: 30, Tetrominoes: 32, Lines Cleared: 0
# Game 11/20 - Score: 26, Tetrominoes: 28, Lines Cleared: 0
# Game 12/20 - Score: 39, Tetrominoes: 31, Lines Cleared: 1
# Game 13/20 - Score: 30, Tetrominoes: 32, Lines Cleared: 0
# Game 14/20 - Score: 26, Tetrominoes: 28, Lines Cleared: 0
# Game 15/20 - Score: 31, Tetrominoes: 33, Lines Cleared: 0
# Game 16/20 - Score: 29, Tetrominoes: 31, Lines Cleared: 0
# Game 17/20 - Score: 23, Tetrominoes: 25, Lines Cleared: 0
# Game 18/20 - Score: 31, Tetrominoes: 33, Lines Cleared: 0
# Game 19/20 - Score: 27, Tetrominoes: 29, Lines Cleared: 0
# Game 20/20 - Score: 38, Tetrominoes: 30, Lines Cleared: 1
#
# Evaluation Results:
# Average Score: 31.0
# Average Tetrominoes: 32.0
# Average Lines Cleared: 0.1
