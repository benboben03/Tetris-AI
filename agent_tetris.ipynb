# %%
from random import random, randint, sample

import numpy as np
import torch
import torch.nn as nn

import cv2
from tetris import Tetris
from collections import deque

# %% [markdown]
# ## Deep Q Learning Network

# %%
class DQN(nn.Module):
    def __init__(self):
        super(DQN, self).__init__()

        self.conv1 = nn.Sequential(nn.Linear(4, 64), nn.ReLU(inplace=True))
        self.conv2 = nn.Sequential(nn.Linear(64, 64), nn.ReLU(inplace=True))
        self.conv3 = nn.Sequential(nn.Linear(64, 1))

        self._create_weights()

    def _create_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)

        return x

# %%
# DQN for modified environment with increased state space

class DQN(nn.Module):
    def __init__(self, input_size=8):
        super(DQN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(128)
        )

        self.conv2 = nn.Sequential(
            nn.Linear(128, 128),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(128)
        )

        self.conv3 = nn.Sequential(
            nn.Linear(128, 64),
            nn.ReLU(inplace=True)
        )

        # Output layer
        self.output = nn.Linear(64, 1)

        self._initialize_weights()

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.output(x)
        return x

# %% [markdown]
# ## Global Constants

# %%
WIDTH = 10  # Width of board
HEIGHT = 20  # Height of board
BLOCK_SIZE = 30  # Block size when rendering
BATCH_SIZE = 512  # High batch size
LEARNING_RATE = 1e-3
GAMMA = 0.99
INITIAL_EPSILON = 1.0
FINAL_EPSILON = 1e-3
NUM_DECAY_EPOCHS = 1350
NUM_EPOCHS = 3000
SAVE_INTERVAL = 250
REPLAY_MEMORY_SIZE = 22000

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cuda')

# %% [markdown]
# ## Training Loop Using Epsilon Greedy and Experience Replay

# %%
def train():
    torch.manual_seed(42)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(42)

    env = Tetris(width=WIDTH, height=HEIGHT, block_size=BLOCK_SIZE)
    model = DQN().to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
    criterion = nn.MSELoss()

    state = env.reset().to(DEVICE)
    replay_memory = deque(maxlen=REPLAY_MEMORY_SIZE)
    epoch = 0

    while epoch < NUM_EPOCHS:
        next_steps = env.get_next_states()
        # Epsilon Greedy
        epsilon = FINAL_EPSILON + (max(NUM_DECAY_EPOCHS - epoch, 0) * 
                                   (INITIAL_EPSILON - FINAL_EPSILON) / NUM_DECAY_EPOCHS)
        next_actions, next_states = zip(*next_steps.items())
        next_states = torch.stack(next_states).to(DEVICE)

        #print(next_states.shape)

        model.eval()
        with torch.no_grad():
            predictions = model(next_states)[:, 0]
        model.train()

        if random() <= epsilon:
            index = randint(0, len(next_steps) - 1)
        else:
            index = torch.argmax(predictions).item()

        next_state = next_states[index, :]
        action = next_actions[index]

        reward, done = env.step(action, render=True)
        next_state = next_state.to(DEVICE)
        replay_memory.append([state, reward, next_state, done])

        if done:
            final_score = env.score
            final_tetrominoes = env.tetrominoes
            final_cleared_lines = env.cleared_lines
            state = env.reset().to(DEVICE)
        else:
            state = next_state
            continue

        if len(replay_memory) < REPLAY_MEMORY_SIZE / 10:
            continue

        epoch += 1
        batch = sample(replay_memory, min(len(replay_memory), BATCH_SIZE))
        state_batch, reward_batch, next_state_batch, done_batch = zip(*batch)
        state_batch = torch.stack(tuple(state for state in state_batch)).to(DEVICE)
        reward_batch = torch.from_numpy(np.array(reward_batch, dtype=np.float32)[:, None]).to(DEVICE)
        next_state_batch = torch.stack(tuple(state for state in next_state_batch)).to(DEVICE)

        q_values = model(state_batch)
        model.eval()
        with torch.no_grad():
            next_prediction_batch = model(next_state_batch)
        model.train()
 
        # Compute the target Q-values for each transition
        y_values = [
            reward if done else reward + GAMMA * prediction
            for reward, done, prediction in zip(reward_batch, done_batch, next_prediction_batch)
        ]
        y_tensor = torch.tensor(y_values, dtype=torch.float32, device=DEVICE)
        y_batch = y_tensor[:, None]

        optimizer.zero_grad()
        loss = criterion(q_values, y_batch)
        loss.backward()
        optimizer.step()

        print("Epoch: {}/{}, Action: {}, Score: {}, Tetrominoes {}, Cleared lines: {}".format(
            epoch,
            NUM_EPOCHS,
            action,
            final_score,
            final_tetrominoes,
            final_cleared_lines))

        if epoch > 0 and epoch % SAVE_INTERVAL == 0:
            torch.save(model.state_dict(), "policy_net.pth")

    torch.save(model.state_dict(), "policy_net.pth")
    return model

# %%
agent_tetris = train()
# Out:
# Epoch: 1/3000, Action: (5, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 2/3000, Action: (7, 3), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 3/3000, Action: (2, 2), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 4/3000, Action: (4, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 5/3000, Action: (5, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 6/3000, Action: (6, 1), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch: 7/3000, Action: (4, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 8/3000, Action: (1, 0), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch: 9/3000, Action: (2, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 10/3000, Action: (2, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 11/3000, Action: (8, 3), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 12/3000, Action: (3, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 13/3000, Action: (4, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 14/3000, Action: (6, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 15/3000, Action: (4, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 16/3000, Action: (5, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 17/3000, Action: (3, 0), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 18/3000, Action: (2, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 19/3000, Action: (1, 1), Score: 9, Tetrominoes 11, Cleared lines: 0
# Epoch: 20/3000, Action: (4, 3), Score: 26, Tetrominoes 18, Cleared lines: 1
# Epoch: 21/3000, Action: (6, 3), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 22/3000, Action: (0, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 23/3000, Action: (1, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 24/3000, Action: (1, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 25/3000, Action: (8, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 26/3000, Action: (5, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 27/3000, Action: (2, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 28/3000, Action: (3, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 29/3000, Action: (4, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 30/3000, Action: (6, 1), Score: 6, Tetrominoes 8, Cleared lines: 0
# Epoch: 31/3000, Action: (1, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 32/3000, Action: (5, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 33/3000, Action: (2, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 34/3000, Action: (3, 2), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 35/3000, Action: (0, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 36/3000, Action: (5, 1), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch: 37/3000, Action: (8, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 38/3000, Action: (5, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 39/3000, Action: (6, 1), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 40/3000, Action: (1, 3), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 41/3000, Action: (1, 0), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 42/3000, Action: (7, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 43/3000, Action: (2, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 44/3000, Action: (6, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 45/3000, Action: (5, 3), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 46/3000, Action: (3, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 47/3000, Action: (1, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 48/3000, Action: (2, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 49/3000, Action: (4, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 50/3000, Action: (1, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 51/3000, Action: (4, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 52/3000, Action: (6, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 53/3000, Action: (1, 0), Score: 33, Tetrominoes 25, Cleared lines: 1
# Epoch: 54/3000, Action: (5, 3), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 55/3000, Action: (5, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 56/3000, Action: (4, 0), Score: 23, Tetrominoes 25, Cleared lines: 0
# Epoch: 57/3000, Action: (4, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 58/3000, Action: (5, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 59/3000, Action: (3, 0), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch:
 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 1981/3000, Action: (5, 0), Score: 521, Tetrominoes 133, Cleared lines: 39
# Epoch: 1982/3000, Action: (1, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 1983/3000, Action: (3, 1), Score: 312, Tetrominoes 94, Cleared lines: 22
# Epoch: 1984/3000, Action: (6, 1), Score: 131, Tetrominoes 53, Cleared lines: 8
# Epoch: 1985/3000, Action: (3, 1), Score: 849, Tetrominoes 201, Cleared lines: 65
# Epoch: 1986/3000, Action: (6, 0), Score: 195, Tetrominoes 67, Cleared lines: 13
# Epoch: 1987/3000, Action: (4, 1), Score: 385, Tetrominoes 107, Cleared lines: 28
# Epoch: 1988/3000, Action: (5, 3), Score: 271, Tetrominoes 83, Cleared lines: 19
# Epoch: 1989/3000, Action: (8, 1), Score: 111, Tetrominoes 53, Cleared lines: 6
# Epoch: 1990/3000, Action: (1, 1), Score: 312, Tetrominoes 94, Cleared lines: 22
# Epoch: 1991/3000, Action: (6, 1), Score: 320, Tetrominoes 92, Cleared lines: 23
# Epoch: 1992/3000, Action: (0, 0), Score: 222, Tetrominoes 74, Cleared lines: 15
# Epoch: 1993/3000, Action: (0, 1), Score: 472, Tetrominoes 124, Cleared lines: 35
# Epoch: 1994/3000, Action: (8, 3), Score: 444, Tetrominoes 116, Cleared lines: 33
# Epoch: 1995/3000, Action: (0, 1), Score: 272, Tetrominoes 84, Cleared lines: 19
# Epoch: 1996/3000, Action: (8, 1), Score: 574, Tetrominoes 146, Cleared lines: 43
# Epoch: 1997/3000, Action: (3, 0), Score: 261, Tetrominoes 83, Cleared lines: 18
# Epoch: 1998/3000, Action: (3, 0), Score: 485, Tetrominoes 127, Cleared lines: 36
# Epoch: 1999/3000, Action: (4, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 2000/3000, Action: (0, 1), Score: 211, Tetrominoes 73, Cleared lines: 14
# Epoch: 2001/3000, Action: (4, 1), Score: 221, Tetrominoes 73, Cleared lines: 15
# Epoch: 2002/3000, Action: (0, 1), Score: 123, Tetrominoes 55, Cleared lines: 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 agent_tetris = train()
#
# Cell In[6], line 38, in train()
#      35 next_state = next_states[index, :]
#      36 action = next_actions[index]
# ---> 38 reward, done = env.step(action, render=True)
#      39 next_state = next_state.to(DEVICE)
#      40 replay_memory.append([state, reward, next_state, done])
#
# File c:\Users\rohan\Desktop\175\Tetris-AI\tetris.py:274, in Tetris.step(self, action, render, video)
#     272     self.current_pos["y"] += 1
#     273     if render:
# --> 274         self.render(video)
#     276 overflow = self.truncate(self.piece, self.current_pos)
#     277 if overflow:
#
# File c:\Users\rohan\Desktop\175\Tetris-AI\tetris.py:333, in Tetris.render(self, video)
#     330     video.write(img)
#     332 cv2.imshow("Deep Q-Learning Tetris", img)
# --> 333 cv2.waitKey(1)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Record a Single Game with Trained Agent

# %%
# Constants
WIDTH = 10  # Width of the board
HEIGHT = 20  # Height of the board
BLOCK_SIZE = 30  # Block size when rendering
FPS = 100  # Frames per second for video output

OUTPUT_VIDEO = "demo.mp4"

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

agent_tetris = DQN().to(DEVICE)
agent_tetris.load_state_dict(torch.load("policy_net.pth"))
# Out:
# C:\Users\rohan\AppData\Local\Temp\ipykernel_27868\4095406286.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   agent_tetris.load_state_dict(torch.load("expanded_policy_net.pth"))
# <All keys matched successfully>

# %%
def record_game(model):
    """
    Test the Deep Q Network by playing Tetris and rendering the output as a video.
    """
    # Set random seeds for reproducibility
    torch.manual_seed(123)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(123)

    model.eval()  # Set the model to evaluation mode

    env = Tetris(width=WIDTH, height=HEIGHT, block_size=BLOCK_SIZE)
    env.reset()
    model.to(DEVICE)

    video_size = (int(1.5 * WIDTH * BLOCK_SIZE), HEIGHT * BLOCK_SIZE)
    video_writer = cv2.VideoWriter(OUTPUT_VIDEO, cv2.VideoWriter_fourcc(*"mp4v"), FPS, video_size)

    while True:
        next_steps = env.get_next_states()
        next_actions, next_states = zip(*next_steps.items())
        next_states = torch.stack(next_states).to(DEVICE)

        with torch.no_grad():
            predictions = model(next_states)[:, 0]
        best_action_index = torch.argmax(predictions).item()
        action = next_actions[best_action_index]

        _, done = env.step(action, render=True, video=video_writer)

        if done:
            video_writer.release()
            print("Game over. Video saved to:", OUTPUT_VIDEO)
            break
    cv2.destroyAllWindows()

# %%
record_game(agent_tetris)
# Out:
# Game over. Video saved to: expanded_demo.mp4

# %% [markdown]
# ## Get Agent Stats for 20 Games

# %%
FPS = 300
def evaluate_model(model, num_games=20):
    model.eval()
    env = Tetris(width=WIDTH, height=HEIGHT, block_size=BLOCK_SIZE)

    total_score = 0
    total_tetrominoes = 0
    total_lines_cleared = 0

    for _ in range(num_games):
        _ = env.reset().to(DEVICE)
        game_score = 0
        game_tetrominoes = 0
        game_lines_cleared = 0

        while True:
            next_steps = env.get_next_states()
            next_actions, next_states = zip(*next_steps.items())
            next_states = torch.stack(next_states).to(DEVICE)

            with torch.no_grad():
                predictions = model(next_states)[:, 0]
            best_action_index = torch.argmax(predictions).item()
            action = next_actions[best_action_index]

            _, done = env.step(action)

            game_score = env.score
            game_tetrominoes = env.tetrominoes
            game_lines_cleared = env.cleared_lines

            if done:
                break

        # Accumulate totals
        total_score += game_score
        total_tetrominoes += game_tetrominoes
        total_lines_cleared += game_lines_cleared

        #print(f"Game {game + 1}/{num_games} - Score: {game_score}, Tetrominoes: {game_tetrominoes}, Lines Cleared: {game_lines_cleared}")

    # Calculate averages
    avg_score = total_score / num_games
    avg_tetrominoes = total_tetrominoes / num_games
    avg_lines_cleared = total_lines_cleared / num_games

    print(f"\nEvaluation Results:")
    print(f"Average Score: {avg_score}")
    print(f"Average Tetrominoes: {avg_tetrominoes}")
    print(f"Average Lines Cleared: {avg_lines_cleared}")

    return avg_score, avg_tetrominoes, avg_lines_cleared

# %%
avg_score, avg_tetrominoes, avg_lines_cleared = evaluate_model(agent_tetris)
# Out:
# Evaluation Results:
# Average Score: 446.3
# Average Tetrominoes: 118.3
# Average Lines Cleared: 33.0
