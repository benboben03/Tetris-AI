# %%
from random import random, randint, sample

import numpy as np
import torch
import torch.nn as nn

import cv2
from tetris import Tetris
from collections import deque

# %% [markdown]
# ## Deep Q Learning Network

# %%
class DQN(nn.Module):
    def __init__(self):
        super(DQN, self).__init__()

        self.conv1 = nn.Sequential(nn.Linear(4, 64), nn.ReLU(inplace=True))
        self.conv2 = nn.Sequential(nn.Linear(64, 64), nn.ReLU(inplace=True))
        self.conv3 = nn.Sequential(nn.Linear(64, 1))

        self._create_weights()

    def _create_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)

        return x

# %% [markdown]
# ## Global Constants

# %%
WIDTH = 10  # Width of board
HEIGHT = 20  # Height of board
BLOCK_SIZE = 30  # Block size when rendering
BATCH_SIZE = 512  # High batch size
LEARNING_RATE = 1e-3
GAMMA = 0.99
INITIAL_EPSILON = 1.0
FINAL_EPSILON = 1e-3
NUM_DECAY_EPOCHS = 1350
NUM_EPOCHS = 2000
SAVE_INTERVAL = 500
REPLAY_MEMORY_SIZE = 22000

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cuda')

# %%
def train():
    torch.manual_seed(42)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(42)

    env = Tetris(width=WIDTH, height=HEIGHT, block_size=BLOCK_SIZE)
    model = DQN().to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
    criterion = nn.MSELoss()

    state = env.reset().to(DEVICE)
    replay_memory = deque(maxlen=REPLAY_MEMORY_SIZE)
    epoch = 0

    while epoch < NUM_EPOCHS:
        next_steps = env.get_next_states()
        # Exploration or exploitation
        epsilon = FINAL_EPSILON + (max(NUM_DECAY_EPOCHS - epoch, 0) * 
                                   (INITIAL_EPSILON - FINAL_EPSILON) / NUM_DECAY_EPOCHS)
        next_actions, next_states = zip(*next_steps.items())
        next_states = torch.stack(next_states).to(DEVICE)

        model.eval()
        with torch.no_grad():
            predictions = model(next_states)[:, 0]
        model.train()

        if random() <= epsilon:
            index = randint(0, len(next_steps) - 1)
        else:
            index = torch.argmax(predictions).item()

        next_state = next_states[index, :]
        action = next_actions[index]

        reward, done = env.step(action, render=True)
        next_state = next_state.to(DEVICE)
        replay_memory.append([state, reward, next_state, done])

        if done:
            final_score = env.score
            final_tetrominoes = env.tetrominoes
            final_cleared_lines = env.cleared_lines
            state = env.reset().to(DEVICE)
        else:
            state = next_state
            continue

        if len(replay_memory) < REPLAY_MEMORY_SIZE / 10:
            continue

        epoch += 1
        batch = sample(replay_memory, min(len(replay_memory), BATCH_SIZE))
        state_batch, reward_batch, next_state_batch, done_batch = zip(*batch)
        state_batch = torch.stack(tuple(state for state in state_batch)).to(DEVICE)
        reward_batch = torch.from_numpy(np.array(reward_batch, dtype=np.float32)[:, None]).to(DEVICE)
        next_state_batch = torch.stack(tuple(state for state in next_state_batch)).to(DEVICE)

        q_values = model(state_batch)
        model.eval()
        with torch.no_grad():
            next_prediction_batch = model(next_state_batch)
        model.train()

        y_batch = torch.cat(
            tuple(reward if done else reward + GAMMA * prediction for reward, done, prediction in
                  zip(reward_batch, done_batch, next_prediction_batch)))[:, None]

        optimizer.zero_grad()
        loss = criterion(q_values, y_batch)
        loss.backward()
        optimizer.step()

        print("Epoch: {}/{}, Action: {}, Score: {}, Tetrominoes {}, Cleared lines: {}".format(
            epoch,
            NUM_EPOCHS,
            action,
            final_score,
            final_tetrominoes,
            final_cleared_lines))

        if epoch > 0 and epoch % SAVE_INTERVAL == 0:
            torch.save(model.state_dict(), "policy_net.pth")

    torch.save(model.state_dict(), "policy_net.pth")
    return model

# %%
agent_tetris = train()
# Out:
# Epoch: 1/3000, Action: (4, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 2/3000, Action: (3, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 3/3000, Action: (3, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 4/3000, Action: (4, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 5/3000, Action: (3, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 6/3000, Action: (6, 2), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 7/3000, Action: (2, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 8/3000, Action: (5, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 9/3000, Action: (5, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 10/3000, Action: (6, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 11/3000, Action: (7, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 12/3000, Action: (7, 1), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 13/3000, Action: (1, 1), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 14/3000, Action: (3, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 15/3000, Action: (5, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 16/3000, Action: (5, 1), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 17/3000, Action: (3, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 18/3000, Action: (5, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 19/3000, Action: (2, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 20/3000, Action: (5, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 21/3000, Action: (0, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 22/3000, Action: (4, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 23/3000, Action: (4, 1), Score: 25, Tetrominoes 27, Cleared lines: 0
# Epoch: 24/3000, Action: (1, 2), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 25/3000, Action: (3, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 26/3000, Action: (5, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 27/3000, Action: (6, 1), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 28/3000, Action: (6, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 29/3000, Action: (2, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 30/3000, Action: (6, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 31/3000, Action: (7, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 32/3000, Action: (4, 3), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 33/3000, Action: (5, 2), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 34/3000, Action: (0, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 35/3000, Action: (4, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 36/3000, Action: (4, 1), Score: 9, Tetrominoes 11, Cleared lines: 0
# Epoch: 37/3000, Action: (3, 1), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 38/3000, Action: (3, 3), Score: 11, Tetrominoes 13, Cleared lines: 0
# Epoch: 39/3000, Action: (2, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 40/3000, Action: (4, 3), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 41/3000, Action: (5, 1), Score: 27, Tetrominoes 19, Cleared lines: 1
# Epoch: 42/3000, Action: (0, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 43/3000, Action: (5, 3), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 44/3000, Action: (4, 2), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 45/3000, Action: (4, 1), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 46/3000, Action: (1, 1), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 47/3000, Action: (8, 3), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 48/3000, Action: (4, 1), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 49/3000, Action: (6, 1), Score: 24, Tetrominoes 26, Cleared lines: 0
# Epoch: 50/3000, Action: (1, 1), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 51/3000, Action: (5, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 52/3000, Action: (4, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 53/3000, Action: (4, 2), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 54/3000, Action: (3, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 55/3000, Action: (4, 3), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 56/3000, Action: (5, 0), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 57/3000, Action: (6, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 58/3000, Action: (5, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 59/3000, Action: (6, 0), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 60/3000, Action: (6, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 61/3000, Action: (2, 2), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 62/3000, Action: (6, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 63/3000, Action: (2, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 64/3000, Action: (0, 0), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 65/3000, Action: (6, 3), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 66/3000, Action: (2, 2), Score: 13, Tetrominoes 15, Cleared lines: 0
# Epoch: 67/3000, Action: (4, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 68/3000, Action: (6, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 69/3000, Action: (3, 0), Score: 16, Tetrominoes 18, Cleared lines: 0
# Epoch: 70/3000, Action: (4, 0), Score: 19, Tetrominoes 21, Cleared lines: 0
# Epoch: 71/3000, Action: (5, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 72/3000, Action: (6, 0), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 73/3000, Action: (2, 0), Score: 8, Tetrominoes 10, Cleared lines: 0
# Epoch: 74/3000, Action: (6, 3), Score: 14, Tetrominoes 16, Cleared lines: 0
# Epoch: 75/3000, Action: (3, 1), Score: 10, Tetrominoes 12, Cleared lines: 0
# Epoch: 76/3000, Action: (8, 1), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 77/3000, Action: (4, 0), Score: 12, Tetrominoes 14, Cleared lines: 0
# Epoch: 78/3000, Action: (3, 0), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 79/3000, Action: (3, 1), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 80/3000, Action: (6, 2), Score: 17, Tetrominoes 19, Cleared lines: 0
# Epoch: 81/3000, Action: (2, 2), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 82/3000, Action: (2, 0), Score: 18, Tetrominoes 20, Cleared lines: 0
# Epoch: 83/3000, Action: (3, 0), Score: 20, Tetrominoes 22, Cleared lines: 0
# Epoch: 84/3000, Action: (5, 1), Score: 22, Tetrominoes 24, Cleared lines: 0
# Epoch: 85/3000, Action: (4, 0), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch: 86/3000, Action: (8, 1), Score: 21, Tetrominoes 23, Cleared lines: 0
# Epoch: 87/3000, Action: (5, 1), Score: 15, Tetrominoes 17, Cleared lines: 0
# Epoch:
Score: 31, Tetrominoes 33, Cleared lines: 0
# Epoch: 2263/3000, Action: (2, 2), Score: 114, Tetrominoes 46, Cleared lines: 5
# Epoch: 2264/3000, Action: (2, 3), Score: 52, Tetrominoes 34, Cleared lines: 2
# Epoch: 2265/3000, Action: (0, 1), Score: 248, Tetrominoes 60, Cleared lines: 11
# Epoch: 2266/3000, Action: (0, 1), Score: 7481, Tetrominoes 813, Cleared lines: 311
# Epoch: 2267/3000, Action: (3, 1), Score: 69533, Tetrominoes 8515, Cleared lines: 3392
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 train()
#
# Cell In[11], line 36, in train()
#      33 next_state = next_states[index, :]
#      34 action = next_actions[index]
# ---> 36 reward, done = env.step(action, render=True)
#      37 next_state = next_state.to(DEVICE)
#      38 replay_memory.append([state, reward, next_state, done])
#
# File c:\Users\rohan\Desktop\175\Tetris-AI\tetris.py:213, in Tetris.step(self, action, render, video)
#     211     self.current_pos["y"] += 1
#     212     if render:
# --> 213         self.render(video)
#     215 overflow = self.truncate(self.piece, self.current_pos)
#     216 if overflow:
#
# File c:\Users\rohan\Desktop\175\Tetris-AI\tetris.py:272, in Tetris.render(self, video)
#     269     video.write(img)
#     271 cv2.imshow("Deep Q-Learning Tetris", img)
# --> 272 cv2.waitKey(1)
#
# KeyboardInterrupt:

# %%
# Constants
WIDTH = 10  # Width of the board
HEIGHT = 20  # Height of the board
BLOCK_SIZE = 30  # Block size when rendering
FPS = 100  # Frames per second for video output

OUTPUT_VIDEO = "base_demo.mp4"

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

agent_tetris = DQN().to(DEVICE)
agent_tetris.load_state_dict(torch.load("policy_net.pth"))
# Out:
# C:\Users\rohan\AppData\Local\Temp\ipykernel_27192\4281655833.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   agent_tetris.load_state_dict(torch.load("policy_net.pth"))
# <All keys matched successfully>

# %%
def record_game(model):
    """
    Test the Deep Q Network by playing Tetris and rendering the output as a video.
    """
    # Set random seeds for reproducibility
    torch.manual_seed(123)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(123)

    model.eval()  # Set the model to evaluation mode

    env = Tetris(width=WIDTH, height=HEIGHT, block_size=BLOCK_SIZE)
    env.reset()
    model.to(DEVICE)

    video_size = (int(1.5 * WIDTH * BLOCK_SIZE), HEIGHT * BLOCK_SIZE)
    video_writer = cv2.VideoWriter(OUTPUT_VIDEO, cv2.VideoWriter_fourcc(*"mp4v"), FPS, video_size)

    while True:
        next_steps = env.get_next_states()
        next_actions, next_states = zip(*next_steps.items())
        next_states = torch.stack(next_states).to(DEVICE)

        with torch.no_grad():
            predictions = model(next_states)[:, 0]
        best_action_index = torch.argmax(predictions).item()
        action = next_actions[best_action_index]

        _, done = env.step(action, render=True, video=video_writer)

        if done:
            video_writer.release()
            print("Game over. Video saved to:", OUTPUT_VIDEO)
            break
    cv2.destroyAllWindows()

# %%
record_game(agent_tetris)
# Out:
# Game over. Video saved to: base_demo.mp4

# %%
FPS = 300
def evaluate_model(model, num_games=20):
    """
    Evaluate the performance of a trained model over a specified number of games.
    
    Args:
        model (torch.nn.Module): The trained Deep Q-Network model.
        num_games (int): Number of games to run for evaluation.
    
    Returns:
        tuple: Averages of (score, tetrominoes, lines cleared) over the games.
    """
    model.eval()  # Ensure the model is in evaluation mode
    env = Tetris(width=WIDTH, height=HEIGHT, block_size=BLOCK_SIZE)

    total_score = 0
    total_tetrominoes = 0
    total_lines_cleared = 0

    for game in range(num_games):
        state = env.reset().to(DEVICE)
        game_score = 0
        game_tetrominoes = 0
        game_lines_cleared = 0

        while True:
            # Get possible next states
            next_steps = env.get_next_states()
            next_actions, next_states = zip(*next_steps.items())
            next_states = torch.stack(next_states).to(DEVICE)

            # Predict the best action
            with torch.no_grad():
                predictions = model(next_states)[:, 0]
            best_action_index = torch.argmax(predictions).item()
            action = next_actions[best_action_index]

            # Perform the action in the environment
            _, done = env.step(action)

            # Update game statistics
            game_score = env.score
            game_tetrominoes = env.tetrominoes
            game_lines_cleared = env.cleared_lines

            if done:
                break

        # Accumulate totals
        total_score += game_score
        total_tetrominoes += game_tetrominoes
        total_lines_cleared += game_lines_cleared

        #print(f"Game {game + 1}/{num_games} - Score: {game_score}, Tetrominoes: {game_tetrominoes}, Lines Cleared: {game_lines_cleared}")

    # Calculate averages
    avg_score = total_score / num_games
    avg_tetrominoes = total_tetrominoes / num_games
    avg_lines_cleared = total_lines_cleared / num_games

    print(f"\nEvaluation Results:")
    print(f"Average Score: {avg_score}")
    print(f"Average Tetrominoes: {avg_tetrominoes}")
    print(f"Average Lines Cleared: {avg_lines_cleared}")

    return avg_score, avg_tetrominoes, avg_lines_cleared

# %%
avg_score, avg_tetrominoes, avg_lines_cleared = evaluate_model(agent_tetris)
# Out:
# Game 1/20 - Score: 36, Tetrominoes: 38, Lines Cleared: 0
# Game 2/20 - Score: 32, Tetrominoes: 34, Lines Cleared: 0
# Game 3/20 - Score: 29, Tetrominoes: 31, Lines Cleared: 0
# Game 4/20 - Score: 31, Tetrominoes: 33, Lines Cleared: 0
# Game 5/20 - Score: 28, Tetrominoes: 30, Lines Cleared: 0
# Game 6/20 - Score: 30, Tetrominoes: 32, Lines Cleared: 0
# Game 7/20 - Score: 36, Tetrominoes: 38, Lines Cleared: 0
# Game 8/20 - Score: 33, Tetrominoes: 35, Lines Cleared: 0
# Game 9/20 - Score: 35, Tetrominoes: 37, Lines Cleared: 0
# Game 10/20 - Score: 30, Tetrominoes: 32, Lines Cleared: 0
# Game 11/20 - Score: 26, Tetrominoes: 28, Lines Cleared: 0
# Game 12/20 - Score: 39, Tetrominoes: 31, Lines Cleared: 1
# Game 13/20 - Score: 30, Tetrominoes: 32, Lines Cleared: 0
# Game 14/20 - Score: 26, Tetrominoes: 28, Lines Cleared: 0
# Game 15/20 - Score: 31, Tetrominoes: 33, Lines Cleared: 0
# Game 16/20 - Score: 29, Tetrominoes: 31, Lines Cleared: 0
# Game 17/20 - Score: 23, Tetrominoes: 25, Lines Cleared: 0
# Game 18/20 - Score: 31, Tetrominoes: 33, Lines Cleared: 0
# Game 19/20 - Score: 27, Tetrominoes: 29, Lines Cleared: 0
# Game 20/20 - Score: 38, Tetrominoes: 30, Lines Cleared: 1
#
# Evaluation Results:
# Average Score: 31.0
# Average Tetrominoes: 32.0
# Average Lines Cleared: 0.1
